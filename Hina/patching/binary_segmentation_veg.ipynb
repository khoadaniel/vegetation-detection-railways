# %%
import shutil, os
import cv2
import numpy as np
import pandas as pd
import glob
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
from patchify import patchify
import tifffile as tiff
from PIL import Image
import tensorflow as tf
from tensorflow import keras
import segmentation_models as sm
from tensorflow.keras.metrics import MeanIoU
import random
import splitfolders
# Out:
# Segmentation Models: using `keras` framework.

# %% [markdown]
# ## Crop the images and patchify them to 256_patches
# ### the jpgs for 1st 100 files have already been patched to 256 patches  , see folder 256_patches/images
# ### the masks for these files need to be updated by updating the masks with only the label of interest ---> vegetation
# ### folder is 256_patches/masks

# %%
#Now, crop each large image into patches of 256x256. Save them into a directory 
#so we can use data augmentation and read directly from the drive. 
#root_directory = 'tram/'
#
#patch_size = 256
#
##Read images from repsective 'images' subdirectory
##As all images are of different size we have 2 options, either resize or crop
##But, some images are too large and some small. Resizing will change the size of real objects.
##Therefore, we will crop them to a nearest size divisible by 256 and then 
##divide all images into patches of 256x256x3. 
#img_dir=root_directory+"jpgs/"
#for path, subdirs, files in os.walk(img_dir):
#    #print(path)  
#    dirname = path.split(os.path.sep)[-1]
#    #print(dirname)
#    images = os.listdir(path)  #List of all image names in this subdirectory
#    images_subset=images[0:100]
#    #print(images)
#    for i, image_name in enumerate(images_subset):  
#        if image_name.endswith(".jpg"):
#            #print(image_name)
#            image = cv2.imread(path+"/"+image_name, 1)  #Read each image as BGR
#            SIZE_X = (image.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
#            SIZE_Y = (image.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
#            image = Image.fromarray(image)
#            image = image.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
#            #image = image.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
#            image = np.array(image)             
#   
#            #Extract patches from each image
#            print("Now patchifying image:", path+"/"+image_name)
#            patches_img = patchify(image, (256, 256, 3), step=256)  #Step=256 for 256 patches means no overlap
#    
#            for i in range(patches_img.shape[0]):
#                for j in range(patches_img.shape[1]):
#                    
#                    single_patch_img = patches_img[i,j,:,:]
#                    #single_patch_img = (single_patch_img.astype('float32')) / 255. #We will preprocess using one of the backbones
#                    single_patch_img = single_patch_img[0] #Drop the extra unecessary dimension that patchify adds.                               
#                    
#                    cv2.imwrite(root_directory+"256_patches/images/"+
#                               image_name+"patch_"+str(i)+str(j)+".jpg", single_patch_img)
#                    #image_dataset.append(single_patch_img)

# %% [markdown]
# ## repeat from Masks

# %%
#Now do the same as above for masks
 #For this specific dataset we could have added masks to the above code as masks have extension png
root_directory= 'tram/'
patch_size = 256

label_of_interest = 8 # vegeation

mask_dir=root_directory+"uint8/"
for path, subdirs, files in os.walk(mask_dir):
    #print(path)  
    dirname = path.split(os.path.sep)[-1]

    masks = os.listdir(path)  #List of all image names in this subdirectory
    masks_subset=masks[0:100]
    for i, mask_name in enumerate(masks_subset):  
        if mask_name.endswith(".png"):           
            mask = cv2.imread(path+"/"+mask_name, 0)  #Read each image as Grey (or color but remember to map each color to an integer)
            # change 255 to 19 label class
            #temp_mask[:,:,0][temp_mask[:,:,0]!=labels[cls]]=0 
            #mask[:,:][mask[:,:]==255]=0
            #mask[:,:][mask[:,:]==255]=0
            mask[:,:][mask[:,:]!=label_of_interest]=0
            mask[:,:][mask[:,:]==label_of_interest]=1
            SIZE_X = (mask.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
            SIZE_Y = (mask.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
            mask = Image.fromarray(mask)
            mask = mask.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
            #mask = mask.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
            mask = np.array(mask)     

                 
   
            #Extract patches from each image
            print("Now patchifying mask:", path+"/"+mask_name)
            patches_mask = patchify(mask, (256, 256), step=256)  #Step=256 for 256 patches means no overlap
    
            for i in range(patches_mask.shape[0]):
                for j in range(patches_mask.shape[1]):
                    
                    single_patch_mask = patches_mask[i,j,:,:]
                    #single_patch_img = (single_patch_img.astype('float32')) / 255. #No need to scale masks, but you can do it if you want
                    #single_patch_mask = single_patch_mask[0] #Drop the extra unecessary dimension that patchify adds.                               
                    cv2.imwrite(root_directory+"256_patches/masks_veg/"+
                               mask_name+"patch_"+str(i)+str(j)+".png", single_patch_mask)
# Out:
# Now patchifying mask: tram/uint8//rs00001.png
# Now patchifying mask: tram/uint8//rs00003.png
# Now patchifying mask: tram/uint8//rs00006.png
# Now patchifying mask: tram/uint8//rs00015.png
# Now patchifying mask: tram/uint8//rs00023.png
# Now patchifying mask: tram/uint8//rs00026.png
# Now patchifying mask: tram/uint8//rs00031.png
# Now patchifying mask: tram/uint8//rs00039.png
# Now patchifying mask: tram/uint8//rs00041.png
# Now patchifying mask: tram/uint8//rs00042.png
# Now patchifying mask: tram/uint8//rs00055.png
# Now patchifying mask: tram/uint8//rs00060.png
# Now patchifying mask: tram/uint8//rs00061.png
# Now patchifying mask: tram/uint8//rs00070.png
# Now patchifying mask: tram/uint8//rs00079.png
# Now patchifying mask: tram/uint8//rs00086.png
# Now patchifying mask: tram/uint8//rs00087.png
# Now patchifying mask: tram/uint8//rs00092.png
# Now patchifying mask: tram/uint8//rs00095.png
# Now patchifying mask: tram/uint8//rs00096.png
# Now patchifying mask: tram/uint8//rs00097.png
# Now patchifying mask: tram/uint8//rs00105.png
# Now patchifying mask: tram/uint8//rs00106.png
# Now patchifying mask: tram/uint8//rs00118.png
# Now patchifying mask: tram/uint8//rs00129.png
# Now patchifying mask: tram/uint8//rs00132.png
# Now patchifying mask: tram/uint8//rs00134.png
# Now patchifying mask: tram/uint8//rs00135.png
# Now patchifying mask: tram/uint8//rs00136.png
# Now patchifying mask: tram/uint8//rs00137.png
# Now patchifying mask: tram/uint8//rs00140.png
# Now patchifying mask: tram/uint8//rs00147.png
# Now patchifying mask: tram/uint8//rs00161.png
# Now patchifying mask: tram/uint8//rs00171.png
# Now patchifying mask: tram/uint8//rs00172.png
# Now patchifying mask: tram/uint8//rs00178.png
# Now patchifying mask: tram/uint8//rs00186.png
# Now patchifying mask: tram/uint8//rs00187.png
# Now patchifying mask: tram/uint8//rs00188.png
# Now patchifying mask: tram/uint8//rs00197.png
# Now patchifying mask: tram/uint8//rs00199.png
# Now patchifying mask: tram/uint8//rs00201.png
# Now patchifying mask: tram/uint8//rs00202.png
# Now patchifying mask: tram/uint8//rs00205.png
# Now patchifying mask: tram/uint8//rs00206.png
# Now patchifying mask: tram/uint8//rs00208.png
# Now patchifying mask: tram/uint8//rs00219.png
# Now patchifying mask: tram/uint8//rs00222.png
# Now patchifying mask: tram/uint8//rs00223.png
# Now patchifying mask: tram/uint8//rs00229.png
# Now patchifying mask: tram/uint8//rs00230.png
# Now patchifying mask: tram/uint8//rs00237.png
# Now patchifying mask: tram/uint8//rs00242.png
# Now patchifying mask: tram/uint8//rs00257.png
# Now patchifying mask: tram/uint8//rs00258.png
# Now patchifying mask: tram/uint8//rs00262.png
# Now patchifying mask: tram/uint8//rs00275.png
# Now patchifying mask: tram/uint8//rs00281.png
# Now patchifying mask: tram/uint8//rs00284.png
# Now patchifying mask: tram/uint8//rs00296.png
# Now patchifying mask: tram/uint8//rs00300.png
# Now patchifying mask: tram/uint8//rs00313.png
# Now patchifying mask: tram/uint8//rs00316.png
# Now patchifying mask: tram/uint8//rs00320.png
# Now patchifying mask: tram/uint8//rs00321.png
# Now patchifying mask: tram/uint8//rs00324.png
# Now patchifying mask: tram/uint8//rs00330.png
# Now patchifying mask: tram/uint8//rs00336.png
# Now patchifying mask: tram/uint8//rs00340.png
# Now patchifying mask: tram/uint8//rs00345.png
# Now patchifying mask: tram/uint8//rs00349.png
# Now patchifying mask: tram/uint8//rs00351.png
# Now patchifying mask: tram/uint8//rs00363.png
# Now patchifying mask: tram/uint8//rs00366.png
# Now patchifying mask: tram/uint8//rs00376.png
# Now patchifying mask: tram/uint8//rs00395.png
# Now patchifying mask: tram/uint8//rs00396.png
# Now patchifying mask: tram/uint8//rs00398.png
# Now patchifying mask: tram/uint8//rs00410.png
# Now patchifying mask: tram/uint8//rs00421.png
# Now patchifying mask: tram/uint8//rs00435.png
# Now patchifying mask: tram/uint8//rs00437.png
# Now patchifying mask: tram/uint8//rs00444.png
# Now patchifying mask: tram/uint8//rs00453.png
# Now patchifying mask: tram/uint8//rs00455.png
# Now patchifying mask: tram/uint8//rs00458.png
# Now patchifying mask: tram/uint8//rs00462.png
# Now patchifying mask: tram/uint8//rs00469.png
# Now patchifying mask: tram/uint8//rs00470.png
# Now patchifying mask: tram/uint8//rs00485.png
# Now patchifying mask: tram/uint8//rs00488.png
# Now patchifying mask: tram/uint8//rs00492.png
# Now patchifying mask: tram/uint8//rs00494.png
# Now patchifying mask: tram/uint8//rs00497.png
# Now patchifying mask: tram/uint8//rs00529.png
# Now patchifying mask: tram/uint8//rs00540.png
# Now patchifying mask: tram/uint8//rs00542.png
# Now patchifying mask: tram/uint8//rs00544.png
# Now patchifying mask: tram/uint8//rs00549.png
# Now patchifying mask: tram/uint8//rs00560.png

# %% [markdown]
# ## sanity check after patching

# %%
train_img_dir = "tram/256_patches/images/"
train_mask_dir = "tram/256_patches/masks_veg/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))


img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(train_img_dir+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot =cv2.imread(train_mask_dir+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))
plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')
plt.subplot(122)
plt.imshow(mask_for_plot, cmap='gray')
plt.title('Mask')
plt.show()

# %% [markdown]
# ### delete the useless image patches

# %%
###########################################################################

#Now, let us copy images and masks with real information to a new folder.
# real information = if mask has decent amount of labels other than 0. 

useless=0  #Useless image counter
for img in range(len(img_list)):   #Using t1_list as all lists are of same size
    img_name=img_list[img]
    mask_name = msk_list[img]
    print("Now preparing image and masks number: ", img)
      
    temp_image=cv2.imread(train_img_dir+img_list[img], 1) # read as colored
   
    temp_mask=cv2.imread(train_mask_dir+msk_list[img], 0) # read as greyscale
    #temp_mask=temp_mask.astype(np.uint8)
    
    val, counts = np.unique(temp_mask, return_counts=True)
    
    if (1 - (counts[0]/counts.sum())) > 0.05:  #At least 5% useful area with labels that are not 0
        print("Save Me")
        cv2.imwrite('tram/256_patches/useful/images/'+img_name, temp_image)
        cv2.imwrite('tram/256_patches/useful/masks/'+mask_name, temp_mask)
        
    else:
        print("I am useless")   
        useless +=1
# Out:
# Now preparing image and masks number:  0
# I am useless
# Now preparing image and masks number:  1
# I am useless
# Now preparing image and masks number:  2
# I am useless
# Now preparing image and masks number:  3
# I am useless
# Now preparing image and masks number:  4
# I am useless
# Now preparing image and masks number:  5
# Save Me
# Now preparing image and masks number:  6
# Save Me
# Now preparing image and masks number:  7
# I am useless
# Now preparing image and masks number:  8
# I am useless
# Now preparing image and masks number:  9
# I am useless
# Now preparing image and masks number:  10
# I am useless
# Now preparing image and masks number:  11
# I am useless
# Now preparing image and masks number:  12
# Save Me
# Now preparing image and masks number:  13
# I am useless
# Now preparing image and masks number:  14
# I am useless
# Now preparing image and masks number:  15
# I am useless
# Now preparing image and masks number:  16
# I am useless
# Now preparing image and masks number:  17
# I am useless
# Now preparing image and masks number:  18
# I am useless
# Now preparing image and masks number:  19
# I am useless
# Now preparing image and masks number:  20
# I am useless
# Now preparing image and masks number:  21
# I am useless
# Now preparing image and masks number:  22
# I am useless
# Now preparing image and masks number:  23
# I am useless
# Now preparing image and masks number:  24
# I am useless
# Now preparing image and masks number:  25
# I am useless
# Now preparing image and masks number:  26
# I am useless
# Now preparing image and masks number:  27
# I am useless
# Now preparing image and masks number:  28
# I am useless
# Now preparing image and masks number:  29
# I am useless
# Now preparing image and masks number:  30
# I am useless
# Now preparing image and masks number:  31
# I am useless
# Now preparing image and masks number:  32
# I am useless
# Now preparing image and masks number:  33
# I am useless
# Now preparing image and masks number:  34
# I am useless
# Now preparing image and masks number:  35
# Save Me
# Now preparing image and masks number:  36
# I am useless
# Now preparing image and masks number:  37
# I am useless
# Now preparing image and masks number:  38
# Save Me
# Now preparing image and masks number:  39
# Save Me
# Now preparing image and masks number:  40
# Save Me
# Now preparing image and masks number:  41
# I am useless
# Now preparing image and masks number:  42
# Save Me
# Now preparing image and masks number:  43
# Save Me
# Now preparing image and masks number:  44
# Save Me
# Now preparing image and masks number:  45
# Save Me
# Now preparing image and masks number:  46
# Save Me
# Now preparing image and masks number:  47
# Save Me
# Now preparing image and masks number:  48
# Save Me
# Now preparing image and masks number:  49
# I am useless
# Now preparing image and masks number:  50
# I am useless
# Now preparing image and masks number:  51
# I am useless
# Now preparing image and masks number:  52
# I am useless
# Now preparing image and masks number:  53
# I am useless
# Now preparing image and masks number:  54
# Save Me
# Now preparing image and masks number:  55
# Save Me
# Now preparing image and masks number:  56
# Save Me
# Now preparing image and masks number:  57
# I am useless
# Now preparing image and masks number:  58
# I am useless
# Now preparing image and masks number:  59
# I am useless
# Now preparing image and masks number:  60
# I am useless
# Now preparing image and masks number:  61
# I am useless
# Now preparing image and masks number:  62
# I am useless
# Now preparing image and masks number:  63
# Save Me
# Now preparing image and masks number:  64
# Save Me
# Now preparing image and masks number:  65
# Save Me
# Now preparing image and masks number:  66
# I am useless
# Now preparing image and masks number:  67
# I am useless
# Now preparing image and masks number:  68
# I am useless
# Now preparing image and masks number:  69
# Save Me
# Now preparing image and masks number:  70
# Save Me
# Now preparing image and masks number:  71
# Save Me
# Now preparing image and masks number:  72
# Save Me
# Now preparing image and masks number:  73
# Save Me
# Now preparing image and masks number:  74
# Save Me
# Now preparing image and masks number:  75
# Save Me
# Now preparing image and masks number:  76
# Save Me
# Now preparing image and masks number:  77
# I am useless
# Now preparing image and masks number:  78
# I am useless
# Now preparing image and masks number:  79
# I am useless
# Now preparing image and masks number:  80
# I am useless
# Now preparing image and masks number:  81
# I am useless
# Now preparing image and masks number:  82
# I am useless
# Now preparing image and masks number:  83
# I am useless
# Now preparing image and masks number:  84
# Save Me
# Now preparing image and masks number:  85
# I am useless
# Now preparing image and masks number:  86
# Save Me
# Now preparing image and masks number:  87
# Save Me
# Now preparing image and masks number:  88
# Save Me
# Now preparing image and masks number:  89
# Save Me
# Now preparing image and masks number:  90
# Save Me
# Now preparing image and masks number:  91
# Save Me
# Now preparing image and masks number:  92
# I am useless
# Now preparing image and masks number:  93
# Save Me
# Now preparing image and masks number:  94
# Save Me
# Now preparing image and masks number:  95
# Save Me
# Now preparing image and masks number:  96
# Save Me
# Now preparing image and masks number:  97
# I am useless
# Now preparing image and masks number:  98
# Save Me
# Now preparing image and masks number:  99
# Save Me
# Now preparing image and masks number:  100
# Save Me
# Now preparing image and masks number:  101
# I am useless
# Now preparing image and masks number:  102
# Save Me
# Now preparing image and masks number:  103
# Save Me
# Now preparing image and masks number:  104
# Save Me
# Now preparing image and masks number:  105
# I am useless
# Now preparing image and masks number:  106
# I am useless
# Now preparing image and masks number:  107
# I am useless
# Now preparing image and masks number:  108
# I am useless
# Now preparing image and masks number:  109
# I am useless
# Now preparing image and masks number:  110
# I am useless
# Now preparing image and masks number:  111
# I am useless
# Now preparing image and masks number:  112
# I am useless
# Now preparing image and masks number:  113
# I am useless
# Now preparing image and masks number:  114
# I am useless
# Now preparing image and masks number:  115
# I am useless
# Now preparing image and masks number:  116
# I am useless
# Now preparing image and masks number:  117
# I am useless
# Now preparing image and masks number:  118
# I am useless
# Now preparing image and masks number:  119
# Save Me
# Now preparing image and masks number:  120
# I am useless
# Now preparing image and masks number:  121
# I am useless
# Now preparing image and masks number:  122
# Save Me
# Now preparing image and masks number:  123
# Save Me
# Now preparing image and masks number:  124
# Save Me
# Now preparing image and masks number:  125
# Save Me
# Now preparing image and masks number:  126
# I am useless
# Now preparing image and masks number:  127
# I am useless
# Now preparing image and masks number:  128
# I am useless
# Now preparing image and masks number:  129
# I am useless
# Now preparing image and masks number:  130
# Save Me
# Now preparing image and masks number:  131
# Save Me
# Now preparing image and masks number:  132
# Save Me
# Now preparing image and masks number:  133
# I am useless
# Now preparing image and masks number:  134
# Save Me
# Now preparing image and masks number:  135
# I am useless
# Now preparing image and masks number:  136
# I am useless
# Now preparing image and masks number:  137
# I am useless
# Now preparing image and masks number:  138
# I am useless
# Now preparing image and masks number:  139
# I am useless
# Now preparing image and masks number:  140
# I am useless
# Now preparing image and masks number:  141
# Save Me
# Now preparing image and masks number:  142
# I am useless
# Now preparing image and masks number:  143
# Save Me
# Now preparing image and masks number:  144
# Save Me
# Now preparing image and masks number:  145
# I am useless
# Now preparing image and masks number:  146
# I am useless
# Now preparing image and masks number:  147
# Save Me
# Now preparing image and masks number:  148
# Save Me
# Now preparing image and masks number:  149
# Save Me
# Now preparing image and masks number:  150
# Save Me
# Now preparing image and masks number:  151
# Save Me
# Now preparing image and masks number:  152
# I am useless
# Now preparing image and masks number:  153
# I am useless
# Now preparing image and masks number:  154
# Save Me
# Now preparing image and masks number:  155
# Save Me
# Now preparing image and masks number:  156
# Save Me
# Now preparing image and masks number:  157
# Save Me
# Now preparing image and masks number:  158
# I am useless
# Now preparing image and masks number:  159
# I am useless
# Now preparing image and masks number:  160
# I am useless
# Now preparing image and masks number:  161
# I am useless
# Now preparing image and masks number:  162
# I am useless
# Now preparing image and masks number:  163
# I am useless
# Now preparing image and masks number:  164
# I am useless
# Now preparing image and masks number:  165
# I am useless
# Now preparing image and masks number:  166
# I am useless
# Now preparing image and masks number:  167
# I am useless
# Now preparing image and masks number:  168
# I am useless
# Now preparing image and masks number:  169
# I am useless
# Now preparing image and masks number:  170
# I am useless
# Now preparing image and masks number:  171
# I am useless
# Now preparing image and masks number:  172
# I am useless
# Now preparing image and masks number:  173
# I am useless
# Now preparing image and masks number:  174
# I am useless
# Now preparing image and masks number:  175
# I am useless
# Now preparing image and masks number:  176
# I am useless
# Now preparing image and masks number:  177
# I am useless
# Now preparing image and masks number:  178
# I am useless
# Now preparing image and masks number:  179
# I am useless
# Now preparing image and masks number:  180
# I am useless
# Now preparing image and masks number:  181
# I am useless
# Now preparing image and masks number:  182
# I am useless
# Now preparing image and masks number:  183
# I am useless
# Now preparing image and masks number:  184
# I am useless
# Now preparing image and masks number:  185
# Save Me
# Now preparing image and masks number:  186
# Save Me
# Now preparing image and masks number:  187
# I am useless
# Now preparing image and masks number:  188
# I am useless
# Now preparing image and masks number:  189
# I am useless
# Now preparing image and masks number:  190
# I am useless
# Now preparing image and masks number:  191
# I am useless
# Now preparing image and masks number:  192
# I am useless
# Now preparing image and masks number:  193
# I am useless
# Now preparing image and masks number:  194
# I am useless
# Now preparing image and masks number:  195
# I am useless
# Now preparing image and masks number:  196
# I am useless
# Now preparing image and masks number:  197
# I am useless
# Now preparing image and masks number:  198
# I am useless
# Now preparing image and masks number:  199
# Save Me
# Now preparing image and masks number:  200
# Save Me
# Now preparing image and masks number:  201
# Save Me
# Now preparing image and masks number:  202
# Save Me
# Now preparing image and masks number:  203
# I am useless
# Now preparing image and masks number:  204
# I am useless
# Now preparing image and masks number:  205
# I am useless
# Now preparing image and masks number:  206
# I am useless
# Now preparing image and masks number:  207
# I am useless
# Now preparing image and masks number:  208
# I am useless
# Now preparing image and masks number:  209
# I am useless
# Now preparing image and masks number:  210
# I am useless
# Now preparing image and masks number:  211
# I am useless
# Now preparing image and masks number:  212
# I am useless
# Now preparing image and masks number:  213
# I am useless
# Now preparing image and masks number:  214
# I am useless
# Now preparing image and masks number:  215
# I am useless
# Now preparing image and masks number:  216
# I am useless
# Now preparing image and masks number:  217
# I am useless
# Now preparing image and masks number:  218
# I am useless
# Now preparing image and masks number:  219
# I am useless
# Now preparing image and masks number:  220
# I am useless
# Now preparing image and masks number:  221
# I am useless
# Now preparing image and masks number:  222
# I am useless
# Now preparing image and masks number:  223
# I am useless
# Now preparing image and masks number:  224
# Save Me
# Now preparing image and masks number:  225
# Save Me
# Now preparing image and masks number:  226
# I am useless
# Now preparing image and masks number:  227
# I am useless
# Now preparing image and masks number:  228
# I am useless
# Now preparing image and masks number:  229
# Save Me
# Now preparing image and masks number:  230
# I am useless
# Now preparing image and masks number:  231
# I am useless
# Now preparing image and masks number:  232
# Save Me
# Now preparing image and masks number:  233
# Save Me
# Now preparing image and masks number:  234
# Save Me
# Now preparing image and masks number:  235
# Save Me
# Now preparing image and masks number:  236
# Save Me
# Now preparing image and masks number:  237
# Save Me
# Now preparing image and masks number:  238
# Save Me
# Now preparing image and masks number:  239
# Save Me
# Now preparing image and masks number:  240
# Save Me
# Now preparing image and masks number:  241
# Save Me
# Now preparing image and masks number:  242
# Save Me
# Now preparing image and masks number:  243
# Save Me
# Now preparing image and masks number:  244
# Save Me
# Now preparing image and masks number:  245
# I am useless
# Now preparing image and masks number:  246
# I am useless
# Now preparing image and masks number:  247
# I am useless
# Now preparing image and masks number:  248
# I am useless
# Now preparing image and masks number:  249
# I am useless
# Now preparing image and masks number:  250
# Save Me
# Now preparing image and masks number:  251
# I am useless
# Now preparing image and masks number:  252
# I am useless
# Now preparing image and masks number:  253
# Save Me
# Now preparing image and masks number:  254
# Save Me
# Now preparing image and masks number:  255
# I am useless
# Now preparing image and masks number:  256
# Save Me
# Now preparing image and masks number:  257
# Save Me
# Now preparing image and masks number:  258
# Save Me
# Now preparing image and masks number:  259
# I am useless
# Now preparing image and masks number:  260
# Save Me
# Now preparing image and masks number:  261
# Save Me
# Now preparing image and masks number:  262
# Save Me
# Now preparing image and masks number:  263
# Save Me
# Now preparing image and masks number:  264
# Save Me
# Now preparing image and masks number:  265
# I am useless
# Now preparing image and masks number:  266
# I am useless
# Now preparing image and masks number:  267
# I am useless
# Now preparing image and masks number:  268
# I am useless
# Now preparing image and masks number:  269
# I am useless
# Now preparing image and masks number:  270
# Save Me
# Now preparing image and masks number:  271
# Save Me
# Now preparing image and masks number:  272
# Save Me
# Now preparing image and masks number:  273
# I am useless
# Now preparing image and masks number:  274
# I am useless
# Now preparing image and masks number:  275
# I am useless
# Now preparing image and masks number:  276
# I am useless
# Now preparing image and masks number:  277
# I am useless
# Now preparing image and masks number:  278
# I am useless
# Now preparing image and masks number:  279
# I am useless
# Now preparing image and masks number:  280
# I am useless
# Now preparing image and masks number:  281
# I am useless
# Now preparing image and masks number:  282
# I am useless
# Now preparing image and masks number:  283
# I am useless
# Now preparing image and masks number:  284
# I am useless
# Now preparing image and masks number:  285
# I am useless
# Now preparing image and masks number:  286
# I am useless
# Now preparing image and masks number:  287
# I am useless
# Now preparing image and masks number:  288
# I am useless
# Now preparing image and masks number:  289
# I am useless
# Now preparing image and masks number:  290
# I am useless
# Now preparing image and masks number:  291
# Save Me
# Now preparing image and masks number:  292
# I am useless
# Now preparing image and masks number:  293
# I am useless
# Now preparing image and masks number:  294
# I am useless
# Now preparing image and masks number:  295
# I am useless
# Now preparing image and masks number:  296
# I am useless
# Now preparing image and masks number:  297
# I am useless
# Now preparing image and masks number:  298
# I am useless
# Now preparing image and masks number:  299
# I am useless
# Now preparing image and masks number:  300
# I am useless
# Now preparing image and masks number:  301
# I am useless
# Now preparing image and masks number:  302
# I am useless
# Now preparing image and masks number:  303
# I am useless
# Now preparing image and masks number:  304
# I am useless
# Now preparing image and masks number:  305
# I am useless
# Now preparing image and masks number:  306
# I am useless
# Now preparing image and masks number:  307
# I am useless
# Now preparing image and masks number:  308
# Save Me
# Now preparing image and masks number:  309
# Save Me
# Now preparing image and masks number:  310
# Save Me
# Now preparing image and masks number:  311
# Save Me
# Now preparing image and masks number:  312
# Save Me
# Now preparing image and masks number:  313
# Save Me
# Now preparing image and masks number:  314
# Save Me
# Now preparing image and masks number:  315
# Save Me
# Now preparing image and masks number:  316
# Save Me
# Now preparing image and masks number:  317
# Save Me
# Now preparing image and masks number:  318
# Save Me
# Now preparing image and masks number:  319
# Save Me
# Now preparing image and masks number:  320
# Save Me
# Now preparing image and masks number:  321
# Save Me
# Now preparing image and masks number:  322
# Save Me
# Now preparing image and masks number:  323
# Save Me
# Now preparing image and masks number:  324
# Save Me
# Now preparing image and masks number:  325
# Save Me
# Now preparing image and masks number:  326
# Save Me
# Now preparing image and masks number:  327
# Save Me
# Now preparing image and masks number:  328
# Save Me
# Now preparing image and masks number:  329
# I am useless
# Now preparing image and masks number:  330
# I am useless
# Now preparing image and masks number:  331
# I am useless
# Now preparing image and masks number:  332
# I am useless
# Now preparing image and masks number:  333
# I am useless
# Now preparing image and masks number:  334
# I am useless
# Now preparing image and masks number:  335
# I am useless
# Now preparing image and masks number:  336
# I am useless
# Now preparing image and masks number:  337
# I am useless
# Now preparing image and masks number:  338
# I am useless
# Now preparing image and masks number:  339
# I am useless
# Now preparing image and masks number:  340
# I am useless
# Now preparing image and masks number:  341
# I am useless
# Now preparing image and masks number:  342
# I am useless
# Now preparing image and masks number:  343
# I am useless
# Now preparing image and masks number:  344
# I am useless
# Now preparing image and masks number:  345
# I am useless
# Now preparing image and masks number:  346
# I am useless
# Now preparing image and masks number:  347
# I am useless
# Now preparing image and masks number:  348
# I am useless
# Now preparing image and masks number:  349
# I am useless
# Now preparing image and masks number:  350
# I am useless
# Now preparing image and masks number:  351
# I am useless
# Now preparing image and masks number:  352
# I am useless
# Now preparing image and masks number:  353
# Save Me
# Now preparing image and masks number:  354
# I am useless
# Now preparing image and masks number:  355
# I am useless
# Now preparing image and masks number:  356
# I am useless
# Now preparing image and masks number:  357
# I am useless
# Now preparing image and masks number:  358
# I am useless
# Now preparing image and masks number:  359
# I am useless
# Now preparing image and masks number:  360
# I am useless
# Now preparing image and masks number:  361
# I am useless
# Now preparing image and masks number:  362
# I am useless
# Now preparing image and masks number:  363
# I am useless
# Now preparing image and masks number:  364
# Save Me
# Now preparing image and masks number:  365
# Save Me
# Now preparing image and masks number:  366
# Save Me
# Now preparing image and masks number:  367
# Save Me
# Now preparing image and masks number:  368
# I am useless
# Now preparing image and masks number:  369
# I am useless
# Now preparing image and masks number:  370
# I am useless
# Now preparing image and masks number:  371
# Save Me
# Now preparing image and masks number:  372
# Save Me
# Now preparing image and masks number:  373
# Save Me
# Now preparing image and masks number:  374
# Save Me
# Now preparing image and masks number:  375
# Save Me
# Now preparing image and masks number:  376
# Save Me
# Now preparing image and masks number:  377
# Save Me
# Now preparing image and masks number:  378
# Save Me
# Now preparing image and masks number:  379
# Save Me
# Now preparing image and masks number:  380
# Save Me
# Now preparing image and masks number:  381
# Save Me
# Now preparing image and masks number:  382
# Save Me
# Now preparing image and masks number:  383
# Save Me
# Now preparing image and masks number:  384
# Save Me
# Now preparing image and masks number:  385
# I am useless
# Now preparing image and masks number:  386
# I am useless
# Now preparing image and masks number:  387
# I am useless
# Now preparing image and masks number:  388
# I am useless
# Now preparing image and masks number:  389
# I am useless
# Now preparing image and masks number:  390
# I am useless
# Now preparing image and masks number:  391
# I am useless
# Now preparing image and masks number:  392
# Save Me
# Now preparing image and masks number:  393
# Save Me
# Now preparing image and masks number:  394
# Save Me
# Now preparing image and masks number:  395
# Save Me
# Now preparing image and masks number:  396
# I am useless
# Now preparing image and masks number:  397
# I am useless
# Now preparing image and masks number:  398
# Save Me
# Now preparing image and masks number:  399
# Save Me
# Now preparing image and masks number:  400
# Save Me
# Now preparing image and masks number:  401
# Save Me
# Now preparing image and masks number:  402
# Save Me
# Now preparing image and masks number:  403
# Save Me
# Now preparing image and masks number:  404
# Save Me
# Now preparing image and masks number:  405
# Save Me
# Now preparing image and masks number:  406
# Save Me
# Now preparing image and masks number:  407
# Save Me
# Now preparing image and masks number:  408
# Save Me
# Now preparing image and masks number:  409
# I am useless
# Now preparing image and masks number:  410
# Save Me
# Now preparing image and masks number:  411
# Save Me
# Now preparing image and masks number:  412
# Save Me
# Now preparing image and masks number:  413
# I am useless
# Now preparing image and masks number:  414
# I am useless
# Now preparing image and masks number:  415
# I am useless
# Now preparing image and masks number:  416
# I am useless
# Now preparing image and masks number:  417
# I am useless
# Now preparing image and masks number:  418
# Save Me
# Now preparing image and masks number:  419
# I am useless
# Now preparing image and masks number:  420
# I am useless
# Now preparing image and masks number:  421
# I am useless
# Now preparing image and masks number:  422
# I am useless
# Now preparing image and masks number:  423
# I am useless
# Now preparing image and masks number:  424
# I am useless
# Now preparing image and masks number:  425
# Save Me
# Now preparing image and masks number:  426
# Save Me
# Now preparing image and masks number:  427
# I am useless
# Now preparing image and masks number:  428
# Save Me
# Now preparing image and masks number:  429
# Save Me
# Now preparing image and masks number:  430
# Save Me
# Now preparing image and masks number:  431
# Save Me
# Now preparing image and masks number:  432
# Save Me
# Now preparing image and masks number:  433
# Save Me
# Now preparing image and masks number:  434
# Save Me
# Now preparing image and masks number:  435
# Save Me
# Now preparing image and masks number:  436
# Save Me
# Now preparing image and masks number:  437
# I am useless
# Now preparing image and masks number:  438
# Save Me
# Now preparing image and masks number:  439
# Save Me
# Now preparing image and masks number:  440
# Save Me
# Now preparing image and masks number:  441
# I am useless
# Now preparing image and masks number:  442
# I am useless
# Now preparing image and masks number:  443
# I am useless
# Now preparing image and masks number:  444
# I am useless
# Now preparing image and masks number:  445
# I am useless
# Now preparing image and masks number:  446
# I am useless
# Now preparing image and masks number:  447
# I am useless
# Now preparing image and masks number:  448
# I am useless
# Now preparing image and masks number:  449
# I am useless
# Now preparing image and masks number:  450
# I am useless
# Now preparing image and masks number:  451
# I am useless
# Now preparing image and masks number:  452
# I am useless
# Now preparing image and masks number:  453
# I am useless
# Now preparing image and masks number:  454
# I am useless
# Now preparing image and masks number:  455
# I am useless
# Now preparing image and masks number:  456
# I am useless
# Now preparing image and masks number:  457
# I am useless
# Now preparing image and masks number:  458
# Save Me
# Now preparing image and masks number:  459
# Save Me
# Now preparing image and masks number:  460
# I am useless
# Now preparing image and masks number:  461
# I am useless
# Now preparing image and masks number:  462
# I am useless
# Now preparing image and masks number:  463
# I am useless
# Now preparing image and masks number:  464
# I am useless
# Now preparing image and masks number:  465
# I am useless
# Now preparing image and masks number:  466
# I am useless
# Now preparing image and masks number:  467
# I am useless
# Now preparing image and masks number:  468
# I am useless
# Now preparing image and masks number:  469
# I am useless
# Now preparing image and masks number:  470
# I am useless
# Now preparing image and masks number:  471
# I am useless
# Now preparing image and masks number:  472
# I am useless
# Now preparing image and masks number:  473
# I am useless
# Now preparing image and masks number:  474
# I am useless
# Now preparing image and masks number:  475
# I am useless
# Now preparing image and masks number:  476
# I am useless
# Now preparing image and masks number:  477
# I am useless
# Now preparing image and masks number:  478
# I am useless
# Now preparing image and masks number:  479
# I am useless
# Now preparing image and masks number:  480
# Save Me
# Now preparing image and masks number:  481
# Save Me
# Now preparing image and masks number:  482
# Save Me
# Now preparing image and masks number:  483
# Save Me
# Now preparing image and masks number:  484
# I am useless
# Now preparing image and masks number:  485
# I am useless
# Now preparing image and masks number:  486
# Save Me
# Now preparing image and masks number:  487
# Save Me
# Now preparing image and masks number:  488
# Save Me
# Now preparing image and masks number:  489
# Save Me
# Now preparing image and masks number:  490
# I am useless
# Now preparing image and masks number:  491
# I am useless
# Now preparing image and masks number:  492
# I am useless
# Now preparing image and masks number:  493
# I am useless
# Now preparing image and masks number:  494
# I am useless
# Now preparing image and masks number:  495
# Save Me
# Now preparing image and masks number:  496
# Save Me
# Now preparing image and masks number:  497
# I am useless
# Now preparing image and masks number:  498
# I am useless
# Now preparing image and masks number:  499
# I am useless
# Now preparing image and masks number:  500
# I am useless
# Now preparing image and masks number:  501
# I am useless
# Now preparing image and masks number:  502
# I am useless
# Now preparing image and masks number:  503
# I am useless
# Now preparing image and masks number:  504
# Save Me
# Now preparing image and masks number:  505
# Save Me
# Now preparing image and masks number:  506
# I am useless
# Now preparing image and masks number:  507
# Save Me
# Now preparing image and masks number:  508
# Save Me
# Now preparing image and masks number:  509
# Save Me
# Now preparing image and masks number:  510
# Save Me
# Now preparing image and masks number:  511
# Save Me
# Now preparing image and masks number:  512
# Save Me
# Now preparing image and masks number:  513
# Save Me
# Now preparing image and masks number:  514
# Save Me
# Now preparing image and masks number:  515
# Save Me
# Now preparing image and masks number:  516
# Save Me
# Now preparing image and masks number:  517
# Save Me
# Now preparing image and masks number:  518
# I am useless
# Now preparing image and masks number:  519
# I am useless
# Now preparing image and masks number:  520
# Save Me
# Now preparing image and masks number:  521
# Save Me
# Now preparing image and masks number:  522
# Save Me
# Now preparing image and masks number:  523
# Save Me
# Now preparing image and masks number:  524
# Save Me
# Now preparing image and masks number:  525
# I am useless
# Now preparing image and masks number:  526
# I am useless
# Now preparing image and masks number:  527
# I am useless
# Now preparing image and masks number:  528
# I am useless
# Now preparing image and masks number:  529
# I am useless
# Now preparing image and masks number:  530
# I am useless
# Now preparing image and masks number:  531
# I am useless
# Now preparing image and masks number:  532
# Save Me
# Now preparing image and masks number:  533
# I am useless
# Now preparing image and masks number:  534
# I am useless
# Now preparing image and masks number:  535
# I am useless
# Now preparing image and masks number:  536
# I am useless
# Now preparing image and masks number:  537
# I am useless
# Now preparing image and masks number:  538
# I am useless
# Now preparing image and masks number:  539
# Save Me
# Now preparing image and masks number:  540
# Save Me
# Now preparing image and masks number:  541
# Save Me
# Now preparing image and masks number:  542
# Save Me
# Now preparing image and masks number:  543
# I am useless
# Now preparing image and masks number:  544
# Save Me
# Now preparing image and masks number:  545
# Save Me
# Now preparing image and masks number:  546
# Save Me
# Now preparing image and masks number:  547
# Save Me
# Now preparing image and masks number:  548
# Save Me
# Now preparing image and masks number:  549
# Save Me
# Now preparing image and masks number:  550
# I am useless
# Now preparing image and masks number:  551
# I am useless
# Now preparing image and masks number:  552
# Save Me
# Now preparing image and masks number:  553
# Save Me
# Now preparing image and masks number:  554
# I am useless
# Now preparing image and masks number:  555
# I am useless
# Now preparing image and masks number:  556
# I am useless
# Now preparing image and masks number:  557
# I am useless
# Now preparing image and masks number:  558
# I am useless
# Now preparing image and masks number:  559
# I am useless
# Now preparing image and masks number:  560
# I am useless
# Now preparing image and masks number:  561
# I am useless
# Now preparing image and masks number:  562
# I am useless
# Now preparing image and masks number:  563
# I am useless
# Now preparing image and masks number:  564
# I am useless
# Now preparing image and masks number:  565
# I am useless
# Now preparing image and masks number:  566
# I am useless
# Now preparing image and masks number:  567
# Save Me
# Now preparing image and masks number:  568
# Save Me
# Now preparing image and masks number:  569
# Save Me
# Now preparing image and masks number:  570
# Save Me
# Now preparing image and masks number:  571
# Save Me
# Now preparing image and masks number:  572
# Save Me
# Now preparing image and masks number:  573
# Save Me
# Now preparing image and masks number:  574
# I am useless
# Now preparing image and masks number:  575
# Save Me
# Now preparing image and masks number:  576
# I am useless
# Now preparing image and masks number:  577
# I am useless
# Now preparing image and masks number:  578
# I am useless
# Now preparing image and masks number:  579
# I am useless
# Now preparing image and masks number:  580
# I am useless
# Now preparing image and masks number:  581
# Save Me
# Now preparing image and masks number:  582
# Save Me
# Now preparing image and masks number:  583
# I am useless
# Now preparing image and masks number:  584
# I am useless
# Now preparing image and masks number:  585
# I am useless
# Now preparing image and masks number:  586
# I am useless
# Now preparing image and masks number:  587
# I am useless
# Now preparing image and masks number:  588
# Save Me
# Now preparing image and masks number:  589
# Save Me
# Now preparing image and masks number:  590
# Save Me
# Now preparing image and masks number:  591
# Save Me
# Now preparing image and masks number:  592
# Save Me
# Now preparing image and masks number:  593
# Save Me
# Now preparing image and masks number:  594
# Save Me
# Now preparing image and masks number:  595
# Save Me
# Now preparing image and masks number:  596
# Save Me
# Now preparing image and masks number:  597
# Save Me
# Now preparing image and masks number:  598
# Save Me
# Now preparing image and masks number:  599
# Save Me
# Now preparing image and masks number:  600
# Save Me
# Now preparing image and masks number:  601
# Save Me
# Now preparing image and masks number:  602
# Save Me
# Now preparing image and masks number:  603
# Save Me
# Now preparing image and masks number:  604
# I am useless
# Now preparing image and masks number:  605
# I am useless
# Now preparing image and masks number:  606
# Save Me
# Now preparing image and masks number:  607
# Save Me
# Now preparing image and masks number:  608
# Save Me
# Now preparing image and masks number:  609
# I am useless
# Now preparing image and masks number:  610
# I am useless
# Now preparing image and masks number:  611
# I am useless
# Now preparing image and masks number:  612
# I am useless
# Now preparing image and masks number:  613
# I am useless
# Now preparing image and masks number:  614
# I am useless
# Now preparing image and masks number:  615
# I am useless
# Now preparing image and masks number:  616
# Save Me
# Now preparing image and masks number:  617
# I am useless
# Now preparing image and masks number:  618
# I am useless
# Now preparing image and masks number:  619
# Save Me
# Now preparing image and masks number:  620
# Save Me
# Now preparing image and masks number:  621
# Save Me
# Now preparing image and masks number:  622
# Save Me
# Now preparing image and masks number:  623
# Save Me
# Now preparing image and masks number:  624
# Save Me
# Now preparing image and masks number:  625
# Save Me
# Now preparing image and masks number:  626
# Save Me
# Now preparing image and masks number:  627
# I am useless
# Now preparing image and masks number:  628
# I am useless
# Now preparing image and masks number:  629
# I am useless
# Now preparing image and masks number:  630
# Save Me
# Now preparing image and masks number:  631
# Save Me
# Now preparing image and masks number:  632
# Save Me
# Now preparing image and masks number:  633
# Save Me
# Now preparing image and masks number:  634
# Save Me
# Now preparing image and masks number:  635
# Save Me
# Now preparing image and masks number:  636
# Save Me
# Now preparing image and masks number:  637
# I am useless
# Now preparing image and masks number:  638
# I am useless
# Now preparing image and masks number:  639
# I am useless
# Now preparing image and masks number:  640
# I am useless
# Now preparing image and masks number:  641
# I am useless
# Now preparing image and masks number:  642
# I am useless
# Now preparing image and masks number:  643
# I am useless
# Now preparing image and masks number:  644
# I am useless
# Now preparing image and masks number:  645
# Save Me
# Now preparing image and masks number:  646
# Save Me
# Now preparing image and masks number:  647
# Save Me
# Now preparing image and masks number:  648
# I am useless
# Now preparing image and masks number:  649
# Save Me
# Now preparing image and masks number:  650
# Save Me
# Now preparing image and masks number:  651
# Save Me
# Now preparing image and masks number:  652
# Save Me
# Now preparing image and masks number:  653
# Save Me
# Now preparing image and masks number:  654
# Save Me
# Now preparing image and masks number:  655
# Save Me
# Now preparing image and masks number:  656
# Save Me
# Now preparing image and masks number:  657
# Save Me
# Now preparing image and masks number:  658
# Save Me
# Now preparing image and masks number:  659
# I am useless
# Now preparing image and masks number:  660
# I am useless
# Now preparing image and masks number:  661
# I am useless
# Now preparing image and masks number:  662
# Save Me
# Now preparing image and masks number:  663
# Save Me
# Now preparing image and masks number:  664
# Save Me
# Now preparing image and masks number:  665
# I am useless
# Now preparing image and masks number:  666
# I am useless
# Now preparing image and masks number:  667
# I am useless
# Now preparing image and masks number:  668
# I am useless
# Now preparing image and masks number:  669
# I am useless
# Now preparing image and masks number:  670
# I am useless
# Now preparing image and masks number:  671
# I am useless
# Now preparing image and masks number:  672
# Save Me
# Now preparing image and masks number:  673
# Save Me
# Now preparing image and masks number:  674
# Save Me
# Now preparing image and masks number:  675
# Save Me
# Now preparing image and masks number:  676
# Save Me
# Now preparing image and masks number:  677
# Save Me
# Now preparing image and masks number:  678
# Save Me
# Now preparing image and masks number:  679
# I am useless
# Now preparing image and masks number:  680
# Save Me
# Now preparing image and masks number:  681
# Save Me
# Now preparing image and masks number:  682
# Save Me
# Now preparing image and masks number:  683
# Save Me
# Now preparing image and masks number:  684
# Save Me
# Now preparing image and masks number:  685
# Save Me
# Now preparing image and masks number:  686
# I am useless
# Now preparing image and masks number:  687
# I am useless
# Now preparing image and masks number:  688
# Save Me
# Now preparing image and masks number:  689
# I am useless
# Now preparing image and masks number:  690
# Save Me
# Now preparing image and masks number:  691
# Save Me
# Now preparing image and masks number:  692
# Save Me
# Now preparing image and masks number:  693
# I am useless
# Now preparing image and masks number:  694
# I am useless
# Now preparing image and masks number:  695
# I am useless
# Now preparing image and masks number:  696
# I am useless
# Now preparing image and masks number:  697
# I am useless
# Now preparing image and masks number:  698
# I am useless
# Now preparing image and masks number:  699
# I am useless
# Now preparing image and masks number:  700
# I am useless
# Now preparing image and masks number:  701
# I am useless
# Now preparing image and masks number:  702
# I am useless
# Now preparing image and masks number:  703
# I am useless
# Now preparing image and masks number:  704
# I am useless
# Now preparing image and masks number:  705
# I am useless
# Now preparing image and masks number:  706
# I am useless
# Now preparing image and masks number:  707
# Save Me
# Now preparing image and masks number:  708
# Save Me
# Now preparing image and masks number:  709
# Save Me
# Now preparing image and masks number:  710
# Save Me
# Now preparing image and masks number:  711
# Save Me
# Now preparing image and masks number:  712
# Save Me
# Now preparing image and masks number:  713
# Save Me
# Now preparing image and masks number:  714
# Save Me
# Now preparing image and masks number:  715
# Save Me
# Now preparing image and masks number:  716
# Save Me
# Now preparing image and masks number:  717
# Save Me
# Now preparing image and masks number:  718
# Save Me
# Now preparing image and masks number:  719
# Save Me
# Now preparing image and masks number:  720
# Save Me
# Now preparing image and masks number:  721
# I am useless
# Now preparing image and masks number:  722
# I am useless
# Now preparing image and masks number:  723
# I am useless
# Now preparing image and masks number:  724
# I am useless
# Now preparing image and masks number:  725
# I am useless
# Now preparing image and masks number:  726
# Save Me
# Now preparing image and masks number:  727
# Save Me
# Now preparing image and masks number:  728
# Save Me
# Now preparing image and masks number:  729
# Save Me
# Now preparing image and masks number:  730
# I am useless
# Now preparing image and masks number:  731
# I am useless
# Now preparing image and masks number:  732
# Save Me
# Now preparing image and masks number:  733
# Save Me
# Now preparing image and masks number:  734
# Save Me
# Now preparing image and masks number:  735
# Save Me
# Now preparing image and masks number:  736
# Save Me
# Now preparing image and masks number:  737
# Save Me
# Now preparing image and masks number:  738
# Save Me
# Now preparing image and masks number:  739
# Save Me
# Now preparing image and masks number:  740
# Save Me
# Now preparing image and masks number:  741
# Save Me
# Now preparing image and masks number:  742
# I am useless
# Now preparing image and masks number:  743
# Save Me
# Now preparing image and masks number:  744
# Save Me
# Now preparing image and masks number:  745
# Save Me
# Now preparing image and masks number:  746
# Save Me
# Now preparing image and masks number:  747
# Save Me
# Now preparing image and masks number:  748
# Save Me
# Now preparing image and masks number:  749
# I am useless
# Now preparing image and masks number:  750
# I am useless
# Now preparing image and masks number:  751
# I am useless
# Now preparing image and masks number:  752
# I am useless
# Now preparing image and masks number:  753
# I am useless
# Now preparing image and masks number:  754
# I am useless
# Now preparing image and masks number:  755
# I am useless
# Now preparing image and masks number:  756
# Save Me
# Now preparing image and masks number:  757
# I am useless
# Now preparing image and masks number:  758
# Save Me
# Now preparing image and masks number:  759
# I am useless
# Now preparing image and masks number:  760
# I am useless
# Now preparing image and masks number:  761
# I am useless
# Now preparing image and masks number:  762
# Save Me
# Now preparing image and masks number:  763
# Save Me
# Now preparing image and masks number:  764
# Save Me
# Now preparing image and masks number:  765
# Save Me
# Now preparing image and masks number:  766
# Save Me
# Now preparing image and masks number:  767
# I am useless
# Now preparing image and masks number:  768
# Save Me
# Now preparing image and masks number:  769
# Save Me
# Now preparing image and masks number:  770
# Save Me
# Now preparing image and masks number:  771
# Save Me
# Now preparing image and masks number:  772
# I am useless
# Now preparing image and masks number:  773
# Save Me
# Now preparing image and masks number:  774
# Save Me
# Now preparing image and masks number:  775
# Save Me
# Now preparing image and masks number:  776
# Save Me
# Now preparing image and masks number:  777
# I am useless
# Now preparing image and masks number:  778
# I am useless
# Now preparing image and masks number:  779
# I am useless
# Now preparing image and masks number:  780
# I am useless
# Now preparing image and masks number:  781
# I am useless
# Now preparing image and masks number:  782
# I am useless
# Now preparing image and masks number:  783
# I am useless
# Now preparing image and masks number:  784
# I am useless
# Now preparing image and masks number:  785
# I am useless
# Now preparing image and masks number:  786
# Save Me
# Now preparing image and masks number:  787
# Save Me
# Now preparing image and masks number:  788
# Save Me
# Now preparing image and masks number:  789
# I am useless
# Now preparing image and masks number:  790
# I am useless
# Now preparing image and masks number:  791
# I am useless
# Now preparing image and masks number:  792
# I am useless
# Now preparing image and masks number:  793
# Save Me
# Now preparing image and masks number:  794
# Save Me
# Now preparing image and masks number:  795
# Save Me
# Now preparing image and masks number:  796
# I am useless
# Now preparing image and masks number:  797
# Save Me
# Now preparing image and masks number:  798
# I am useless
# Now preparing image and masks number:  799
# Save Me
# Now preparing image and masks number:  800
# Save Me
# Now preparing image and masks number:  801
# I am useless
# Now preparing image and masks number:  802
# I am useless
# Now preparing image and masks number:  803
# I am useless
# Now preparing image and masks number:  804
# Save Me
# Now preparing image and masks number:  805
# I am useless
# Now preparing image and masks number:  806
# I am useless
# Now preparing image and masks number:  807
# I am useless
# Now preparing image and masks number:  808
# I am useless
# Now preparing image and masks number:  809
# I am useless
# Now preparing image and masks number:  810
# I am useless
# Now preparing image and masks number:  811
# I am useless
# Now preparing image and masks number:  812
# I am useless
# Now preparing image and masks number:  813
# I am useless
# Now preparing image and masks number:  814
# I am useless
# Now preparing image and masks number:  815
# I am useless
# Now preparing image and masks number:  816
# I am useless
# Now preparing image and masks number:  817
# I am useless
# Now preparing image and masks number:  818
# I am useless
# Now preparing image and masks number:  819
# Save Me
# Now preparing image and masks number:  820
# Save Me
# Now preparing image and masks number:  821
# I am useless
# Now preparing image and masks number:  822
# I am useless
# Now preparing image and masks number:  823
# I am useless
# Now preparing image and masks number:  824
# I am useless
# Now preparing image and masks number:  825
# I am useless
# Now preparing image and masks number:  826
# Save Me
# Now preparing image and masks number:  827
# I am useless
# Now preparing image and masks number:  828
# I am useless
# Now preparing image and masks number:  829
# I am useless
# Now preparing image and masks number:  830
# I am useless
# Now preparing image and masks number:  831
# I am useless
# Now preparing image and masks number:  832
# I am useless
# Now preparing image and masks number:  833
# I am useless
# Now preparing image and masks number:  834
# I am useless
# Now preparing image and masks number:  835
# I am useless
# Now preparing image and masks number:  836
# I am useless
# Now preparing image and masks number:  837
# I am useless
# Now preparing image and masks number:  838
# I am useless
# Now preparing image and masks number:  839
# I am useless
# Now preparing image and masks number:  840
# I am useless
# Now preparing image and masks number:  841
# I am useless
# Now preparing image and masks number:  842
# I am useless
# Now preparing image and masks number:  843
# I am useless
# Now preparing image and masks number:  844
# I am useless
# Now preparing image and masks number:  845
# I am useless
# Now preparing image and masks number:  846
# Save Me
# Now preparing image and masks number:  847
# Save Me
# Now preparing image and masks number:  848
# Save Me
# Now preparing image and masks number:  849
# Save Me
# Now preparing image and masks number:  850
# Save Me
# Now preparing image and masks number:  851
# Save Me
# Now preparing image and masks number:  852
# Save Me
# Now preparing image and masks number:  853
# Save Me
# Now preparing image and masks number:  854
# Save Me
# Now preparing image and masks number:  855
# Save Me
# Now preparing image and masks number:  856
# Save Me
# Now preparing image and masks number:  857
# I am useless
# Now preparing image and masks number:  858
# I am useless
# Now preparing image and masks number:  859
# Save Me
# Now preparing image and masks number:  860
# Save Me
# Now preparing image and masks number:  861
# I am useless
# Now preparing image and masks number:  862
# I am useless
# Now preparing image and masks number:  863
# I am useless
# Now preparing image and masks number:  864
# I am useless
# Now preparing image and masks number:  865
# I am useless
# Now preparing image and masks number:  866
# I am useless
# Now preparing image and masks number:  867
# I am useless
# Now preparing image and masks number:  868
# Save Me
# Now preparing image and masks number:  869
# Save Me
# Now preparing image and masks number:  870
# I am useless
# Now preparing image and masks number:  871
# I am useless
# Now preparing image and masks number:  872
# Save Me
# Now preparing image and masks number:  873
# I am useless
# Now preparing image and masks number:  874
# I am useless
# Now preparing image and masks number:  875
# Save Me
# Now preparing image and masks number:  876
# Save Me
# Now preparing image and masks number:  877
# Save Me
# Now preparing image and masks number:  878
# Save Me
# Now preparing image and masks number:  879
# Save Me
# Now preparing image and masks number:  880
# I am useless
# Now preparing image and masks number:  881
# I am useless
# Now preparing image and masks number:  882
# I am useless
# Now preparing image and masks number:  883
# I am useless
# Now preparing image and masks number:  884
# I am useless
# Now preparing image and masks number:  885
# I am useless
# Now preparing image and masks number:  886
# I am useless
# Now preparing image and masks number:  887
# I am useless
# Now preparing image and masks number:  888
# I am useless
# Now preparing image and masks number:  889
# I am useless
# Now preparing image and masks number:  890
# I am useless
# Now preparing image and masks number:  891
# I am useless
# Now preparing image and masks number:  892
# I am useless
# ...
# Now preparing image and masks number:  2510
# Save Me
# Now preparing image and masks number:  2511
# Save Me
# Now preparing image and masks number:  2512
# Save Me
# Now preparing image and masks number:  2513
# Save Me
# Now preparing image and masks number:  2514
# I am useless
# Now preparing image and masks number:  2515
# I am useless
# Now preparing image and masks number:  2516
# I am useless
# Now preparing image and masks number:  2517
# I am useless
# Now preparing image and masks number:  2518
# I am useless
# Now preparing image and masks number:  2519
# Save Me
# Now preparing image and masks number:  2520
# Save Me
# Now preparing image and masks number:  2521
# Save Me
# Now preparing image and masks number:  2522
# I am useless
# Now preparing image and masks number:  2523
# I am useless
# Now preparing image and masks number:  2524
# Save Me
# Now preparing image and masks number:  2525
# Save Me
# Now preparing image and masks number:  2526
# Save Me
# Now preparing image and masks number:  2527
# Save Me
# Now preparing image and masks number:  2528
# Save Me
# Now preparing image and masks number:  2529
# Save Me
# Now preparing image and masks number:  2530
# Save Me
# Now preparing image and masks number:  2531
# Save Me
# Now preparing image and masks number:  2532
# Save Me
# Now preparing image and masks number:  2533
# Save Me
# Now preparing image and masks number:  2534
# I am useless
# Now preparing image and masks number:  2535
# I am useless
# Now preparing image and masks number:  2536
# I am useless
# Now preparing image and masks number:  2537
# I am useless
# Now preparing image and masks number:  2538
# I am useless
# Now preparing image and masks number:  2539
# I am useless
# Now preparing image and masks number:  2540
# I am useless
# Now preparing image and masks number:  2541
# I am useless
# Now preparing image and masks number:  2542
# I am useless
# Now preparing image and masks number:  2543
# I am useless
# Now preparing image and masks number:  2544
# I am useless
# Now preparing image and masks number:  2545
# I am useless
# Now preparing image and masks number:  2546
# I am useless
# Now preparing image and masks number:  2547
# I am useless
# Now preparing image and masks number:  2548
# I am useless
# Now preparing image and masks number:  2549
# I am useless
# Now preparing image and masks number:  2550
# I am useless
# Now preparing image and masks number:  2551
# I am useless
# Now preparing image and masks number:  2552
# I am useless
# Now preparing image and masks number:  2553
# I am useless
# Now preparing image and masks number:  2554
# I am useless
# Now preparing image and masks number:  2555
# Save Me
# Now preparing image and masks number:  2556
# I am useless
# Now preparing image and masks number:  2557
# Save Me
# Now preparing image and masks number:  2558
# Save Me
# Now preparing image and masks number:  2559
# I am useless
# Now preparing image and masks number:  2560
# Save Me
# Now preparing image and masks number:  2561
# Save Me
# Now preparing image and masks number:  2562
# Save Me
# Now preparing image and masks number:  2563
# Save Me
# Now preparing image and masks number:  2564
# Save Me
# Now preparing image and masks number:  2565
# Save Me
# Now preparing image and masks number:  2566
# I am useless
# Now preparing image and masks number:  2567
# I am useless
# Now preparing image and masks number:  2568
# Save Me
# Now preparing image and masks number:  2569
# I am useless
# Now preparing image and masks number:  2570
# I am useless
# Now preparing image and masks number:  2571
# I am useless
# Now preparing image and masks number:  2572
# I am useless
# Now preparing image and masks number:  2573
# I am useless
# Now preparing image and masks number:  2574
# I am useless
# Now preparing image and masks number:  2575
# I am useless
# Now preparing image and masks number:  2576
# I am useless
# Now preparing image and masks number:  2577
# I am useless
# Now preparing image and masks number:  2578
# I am useless
# Now preparing image and masks number:  2579
# I am useless
# Now preparing image and masks number:  2580
# I am useless
# Now preparing image and masks number:  2581
# I am useless
# Now preparing image and masks number:  2582
# I am useless
# Now preparing image and masks number:  2583
# I am useless
# Now preparing image and masks number:  2584
# I am useless
# Now preparing image and masks number:  2585
# Save Me
# Now preparing image and masks number:  2586
# Save Me
# Now preparing image and masks number:  2587
# Save Me
# Now preparing image and masks number:  2588
# I am useless
# Now preparing image and masks number:  2589
# I am useless
# Now preparing image and masks number:  2590
# I am useless
# Now preparing image and masks number:  2591
# I am useless
# Now preparing image and masks number:  2592
# I am useless
# Now preparing image and masks number:  2593
# I am useless
# Now preparing image and masks number:  2594
# I am useless
# Now preparing image and masks number:  2595
# I am useless
# Now preparing image and masks number:  2596
# I am useless
# Now preparing image and masks number:  2597
# I am useless
# Now preparing image and masks number:  2598
# I am useless
# Now preparing image and masks number:  2599
# I am useless
# Now preparing image and masks number:  2600
# I am useless
# Now preparing image and masks number:  2601
# I am useless
# Now preparing image and masks number:  2602
# I am useless
# Now preparing image and masks number:  2603
# I am useless
# Now preparing image and masks number:  2604
# I am useless
# Now preparing image and masks number:  2605
# I am useless
# Now preparing image and masks number:  2606
# I am useless
# Now preparing image and masks number:  2607
# I am useless
# Now preparing image and masks number:  2608
# I am useless
# Now preparing image and masks number:  2609
# I am useless
# Now preparing image and masks number:  2610
# I am useless
# Now preparing image and masks number:  2611
# Save Me
# Now preparing image and masks number:  2612
# Save Me
# Now preparing image and masks number:  2613
# Save Me
# Now preparing image and masks number:  2614
# I am useless
# Now preparing image and masks number:  2615
# I am useless
# Now preparing image and masks number:  2616
# I am useless
# Now preparing image and masks number:  2617
# I am useless
# Now preparing image and masks number:  2618
# I am useless
# Now preparing image and masks number:  2619
# I am useless
# Now preparing image and masks number:  2620
# I am useless
# Now preparing image and masks number:  2621
# I am useless
# Now preparing image and masks number:  2622
# I am useless
# Now preparing image and masks number:  2623
# I am useless
# Now preparing image and masks number:  2624
# I am useless
# Now preparing image and masks number:  2625
# I am useless
# Now preparing image and masks number:  2626
# I am useless
# Now preparing image and masks number:  2627
# I am useless
# Now preparing image and masks number:  2628
# I am useless
# Now preparing image and masks number:  2629
# I am useless
# Now preparing image and masks number:  2630
# I am useless
# Now preparing image and masks number:  2631
# Save Me
# Now preparing image and masks number:  2632
# Save Me
# Now preparing image and masks number:  2633
# I am useless
# Now preparing image and masks number:  2634
# Save Me
# Now preparing image and masks number:  2635
# Save Me
# Now preparing image and masks number:  2636
# Save Me
# Now preparing image and masks number:  2637
# Save Me
# Now preparing image and masks number:  2638
# Save Me
# Now preparing image and masks number:  2639
# Save Me
# Now preparing image and masks number:  2640
# Save Me
# Now preparing image and masks number:  2641
# Save Me
# Now preparing image and masks number:  2642
# Save Me
# Now preparing image and masks number:  2643
# Save Me
# Now preparing image and masks number:  2644
# Save Me
# Now preparing image and masks number:  2645
# Save Me
# Now preparing image and masks number:  2646
# I am useless
# Now preparing image and masks number:  2647
# I am useless
# Now preparing image and masks number:  2648
# I am useless
# Now preparing image and masks number:  2649
# I am useless
# Now preparing image and masks number:  2650
# I am useless
# Now preparing image and masks number:  2651
# I am useless
# Now preparing image and masks number:  2652
# I am useless
# Now preparing image and masks number:  2653
# I am useless
# Now preparing image and masks number:  2654
# Save Me
# Now preparing image and masks number:  2655
# I am useless
# Now preparing image and masks number:  2656
# I am useless
# Now preparing image and masks number:  2657
# I am useless
# Now preparing image and masks number:  2658
# I am useless
# Now preparing image and masks number:  2659
# I am useless
# Now preparing image and masks number:  2660
# Save Me
# Now preparing image and masks number:  2661
# I am useless
# Now preparing image and masks number:  2662
# Save Me
# Now preparing image and masks number:  2663
# Save Me
# Now preparing image and masks number:  2664
# I am useless
# Now preparing image and masks number:  2665
# I am useless
# Now preparing image and masks number:  2666
# I am useless
# Now preparing image and masks number:  2667
# Save Me
# Now preparing image and masks number:  2668
# Save Me
# Now preparing image and masks number:  2669
# Save Me
# Now preparing image and masks number:  2670
# Save Me
# Now preparing image and masks number:  2671
# I am useless
# Now preparing image and masks number:  2672
# I am useless
# Now preparing image and masks number:  2673
# I am useless
# Now preparing image and masks number:  2674
# Save Me
# Now preparing image and masks number:  2675
# Save Me
# Now preparing image and masks number:  2676
# Save Me
# Now preparing image and masks number:  2677
# Save Me
# Now preparing image and masks number:  2678
# I am useless
# Now preparing image and masks number:  2679
# I am useless
# Now preparing image and masks number:  2680
# I am useless
# Now preparing image and masks number:  2681
# Save Me
# Now preparing image and masks number:  2682
# I am useless
# Now preparing image and masks number:  2683
# I am useless
# Now preparing image and masks number:  2684
# I am useless
# Now preparing image and masks number:  2685
# I am useless
# Now preparing image and masks number:  2686
# I am useless
# Now preparing image and masks number:  2687
# I am useless
# Now preparing image and masks number:  2688
# I am useless
# Now preparing image and masks number:  2689
# I am useless
# Now preparing image and masks number:  2690
# I am useless
# Now preparing image and masks number:  2691
# I am useless
# Now preparing image and masks number:  2692
# I am useless
# Now preparing image and masks number:  2693
# Save Me
# Now preparing image and masks number:  2694
# Save Me
# Now preparing image and masks number:  2695
# I am useless
# Now preparing image and masks number:  2696
# I am useless
# Now preparing image and masks number:  2697
# Save Me
# Now preparing image and masks number:  2698
# Save Me
# Now preparing image and masks number:  2699
# I am useless
# Now preparing image and masks number:  2700
# Save Me
# Now preparing image and masks number:  2701
# Save Me
# Now preparing image and masks number:  2702
# I am useless
# Now preparing image and masks number:  2703
# I am useless
# Now preparing image and masks number:  2704
# I am useless
# Now preparing image and masks number:  2705
# I am useless
# Now preparing image and masks number:  2706
# I am useless
# Now preparing image and masks number:  2707
# I am useless
# Now preparing image and masks number:  2708
# I am useless
# Now preparing image and masks number:  2709
# I am useless
# Now preparing image and masks number:  2710
# I am useless
# Now preparing image and masks number:  2711
# I am useless
# Now preparing image and masks number:  2712
# I am useless
# Now preparing image and masks number:  2713
# I am useless
# Now preparing image and masks number:  2714
# I am useless
# Now preparing image and masks number:  2715
# I am useless
# Now preparing image and masks number:  2716
# I am useless
# Now preparing image and masks number:  2717
# I am useless
# Now preparing image and masks number:  2718
# I am useless
# Now preparing image and masks number:  2719
# I am useless
# Now preparing image and masks number:  2720
# I am useless
# Now preparing image and masks number:  2721
# Save Me
# Now preparing image and masks number:  2722
# Save Me
# Now preparing image and masks number:  2723
# Save Me
# Now preparing image and masks number:  2724
# I am useless
# Now preparing image and masks number:  2725
# Save Me
# Now preparing image and masks number:  2726
# Save Me
# Now preparing image and masks number:  2727
# Save Me
# Now preparing image and masks number:  2728
# Save Me
# Now preparing image and masks number:  2729
# Save Me
# Now preparing image and masks number:  2730
# I am useless
# Now preparing image and masks number:  2731
# I am useless
# Now preparing image and masks number:  2732
# I am useless
# Now preparing image and masks number:  2733
# I am useless
# Now preparing image and masks number:  2734
# I am useless
# Now preparing image and masks number:  2735
# I am useless
# Now preparing image and masks number:  2736
# I am useless
# Now preparing image and masks number:  2737
# I am useless
# Now preparing image and masks number:  2738
# I am useless
# Now preparing image and masks number:  2739
# I am useless
# Now preparing image and masks number:  2740
# I am useless
# Now preparing image and masks number:  2741
# I am useless
# Now preparing image and masks number:  2742
# I am useless
# Now preparing image and masks number:  2743
# I am useless
# Now preparing image and masks number:  2744
# I am useless
# Now preparing image and masks number:  2745
# I am useless
# Now preparing image and masks number:  2746
# I am useless
# Now preparing image and masks number:  2747
# Save Me
# Now preparing image and masks number:  2748
# Save Me
# Now preparing image and masks number:  2749
# Save Me
# Now preparing image and masks number:  2750
# Save Me
# Now preparing image and masks number:  2751
# I am useless
# Now preparing image and masks number:  2752
# I am useless
# Now preparing image and masks number:  2753
# I am useless
# Now preparing image and masks number:  2754
# Save Me
# Now preparing image and masks number:  2755
# Save Me
# Now preparing image and masks number:  2756
# Save Me
# Now preparing image and masks number:  2757
# Save Me
# Now preparing image and masks number:  2758
# Save Me
# Now preparing image and masks number:  2759
# Save Me
# Now preparing image and masks number:  2760
# Save Me
# Now preparing image and masks number:  2761
# Save Me
# Now preparing image and masks number:  2762
# Save Me
# Now preparing image and masks number:  2763
# Save Me
# Now preparing image and masks number:  2764
# Save Me
# Now preparing image and masks number:  2765
# I am useless
# Now preparing image and masks number:  2766
# I am useless
# Now preparing image and masks number:  2767
# I am useless
# Now preparing image and masks number:  2768
# I am useless
# Now preparing image and masks number:  2769
# I am useless
# Now preparing image and masks number:  2770
# I am useless
# Now preparing image and masks number:  2771
# I am useless
# Now preparing image and masks number:  2772
# I am useless
# Now preparing image and masks number:  2773
# Save Me
# Now preparing image and masks number:  2774
# Save Me
# Now preparing image and masks number:  2775
# Save Me
# Now preparing image and masks number:  2776
# Save Me
# Now preparing image and masks number:  2777
# I am useless
# Now preparing image and masks number:  2778
# Save Me
# Now preparing image and masks number:  2779
# I am useless
# Now preparing image and masks number:  2780
# Save Me
# Now preparing image and masks number:  2781
# Save Me
# Now preparing image and masks number:  2782
# Save Me
# Now preparing image and masks number:  2783
# Save Me
# Now preparing image and masks number:  2784
# Save Me
# Now preparing image and masks number:  2785
# Save Me
# Now preparing image and masks number:  2786
# Save Me
# Now preparing image and masks number:  2787
# Save Me
# Now preparing image and masks number:  2788
# Save Me
# Now preparing image and masks number:  2789
# I am useless
# Now preparing image and masks number:  2790
# Save Me
# Now preparing image and masks number:  2791
# Save Me
# Now preparing image and masks number:  2792
# Save Me
# Now preparing image and masks number:  2793
# I am useless
# Now preparing image and masks number:  2794
# I am useless
# Now preparing image and masks number:  2795
# I am useless
# Now preparing image and masks number:  2796
# I am useless
# Now preparing image and masks number:  2797
# I am useless
# Now preparing image and masks number:  2798
# I am useless
# Now preparing image and masks number:  2799
# I am useless

# %%
print("Total images are: ", len(img_list)) # 2800
print("Total useful images are: ", len(img_list)-useless)  # 1158
print("Total useless images are: ", useless) # 1642
# Out:
# Total images are:  2800
# Total useful images are:  1158
# Total useless images are:  1642

# %% [markdown]
# ## sanity check after extracting useful patches

# %%
train_img_dir_use = "tram/256_patches/useful/images/"
train_mask_dir_use = "tram/256_patches/useful/masks/"

img_list = os.listdir(train_img_dir_use)
msk_list = os.listdir(train_mask_dir_use)

num_images = len(os.listdir(train_img_dir_use))


img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(train_img_dir_use+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot =cv2.imread(train_mask_dir_use+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))
plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')
plt.subplot(122)
plt.imshow(mask_for_plot, cmap='gray')
plt.title('Mask')
plt.show()

# %% [markdown]
# # split the tram images to train and val

# %%
input_folder = 'tram/256_patches/useful/'
output_folder = 'tram/traintest_bin/'
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.80, .20), group_prefix=None) # default value
# Out:
# Copying files: 2316 files [01:36, 23.93 files/s]

# %% [markdown]
# #### manually adjusting the folders to use image_from_directory of keras

# %% [markdown]
# # Train

# %%
# Data Understanding

train_img_dir = "tram/split_data_aug/train_images/train/"
train_mask_dir = "tram/split_data_aug/train_masks/train/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))


img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(train_img_dir+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot =cv2.imread(train_mask_dir+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))
plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')
plt.subplot(122)
plt.imshow(mask_for_plot, cmap='gray')
plt.title('Mask')
plt.show()

# %%
seed=24
batch_size= 16
n_classes=2

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
from keras.utils import to_categorical

# %% [markdown]
# ## Train the Generators with Preprocessed Models
# ### Use this to preprocess input for transfer learning

# %%
BACKBONE = 'resnet34'
preprocess_input = sm.get_preprocessing(BACKBONE)

# %% [markdown]
# ## Preprocess

# %%
#Define a function to perform additional preprocessing after datagen.
#For example, scale images, convert masks to categorical, etc. 
def preprocess_data(img, mask, num_class):
    #Scale images
    img = scaler.fit_transform(img.reshape(-1, img.shape[-1])).reshape(img.shape)
    img = preprocess_input(img)  #Preprocess based on the pretrained backbone...
    #Convert mask to one-hot
    mask = to_categorical(mask, num_class)
      
    return (img,mask)

# %% [markdown]
# ## Generator

# %%
#!pip install Keras-Preprocessing
# Out:
# Requirement already satisfied: Keras-Preprocessing in c:\users\hinat\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\hinat\anaconda3\lib\site-packages (from Keras-Preprocessing) (1.20.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\hinat\anaconda3\lib\site-packages (from Keras-Preprocessing) (1.16.0)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#We are not doing any rotation or zoom to make sure mask values are not interpolated.
#It is important to keep pixel values in mask as 0, 1, 2, 3, ..... 18

def trainGenerator(train_img_path, train_mask_path, num_class):
    
    img_data_gen_args = dict(horizontal_flip=True,
                      vertical_flip=True,
                      fill_mode='reflect')
    
    image_datagen = ImageDataGenerator(**img_data_gen_args)
    mask_datagen = ImageDataGenerator(**img_data_gen_args)
    
    #flow_from_directory
    image_generator = image_datagen.flow_from_directory(
        train_img_path,
        class_mode = None,
        batch_size = batch_size,
        seed = seed)# use same same for img and mask
    
    mask_generator = mask_datagen.flow_from_directory(
        train_mask_path,
        class_mode = None,
        color_mode = 'grayscale',
        batch_size = batch_size,
        seed = seed)# use same seed for img and masks
    
    train_generator = zip(image_generator, mask_generator)
    
    for (img, mask) in train_generator:
        img, mask = preprocess_data(img, mask, num_class)
        yield (img, mask) # yield the preprocessed images from the train_generator images in batches of batch_size=4

# %%
train_img_path = "tram/split_data_aug/train_images/"
train_mask_path = "tram/split_data_aug/train_masks/"
train_img_gen = trainGenerator(train_img_path, train_mask_path, num_class=2)

val_img_path = "tram/split_data_aug/val_images/"
val_mask_path = "tram/split_data_aug/val_masks/"
val_img_gen = trainGenerator(val_img_path, val_mask_path, num_class=2)

# %% [markdown]
# ### traverse through images generated by image generator to do sanity check for images and masks

# %%
#Make sure the generator is working and that images and masks are indeed lined up. 
#Verify generator.... In python 3 next() is renamed as __next__()
x, y = train_img_gen.__next__()

for i in range(0,4):
    image = x[i]
    mask = np.argmax(y[i], axis=2)
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.show()

x_val, y_val = val_img_gen.__next__()

for i in range(0,4):
    image = x_val[i]
    mask = np.argmax(y_val[i], axis=2)
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.show()
# Out:
# Found 926 images belonging to 1 classes.
# Found 926 images belonging to 1 classes.
# Found 232 images belonging to 1 classes.
# Found 232 images belonging to 1 classes.

# %% [markdown]
# # Define the Model

# %%
###########################################################################
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('tram/split_data_aug/train_images/train/'))
num_val_images = len(os.listdir('tram/split_data_aug/val_images/val/'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size


IMG_HEIGHT = x.shape[1]
IMG_WIDTH  = x.shape[2]
IMG_CHANNELS = x.shape[3]

n_classes=2

# %% [markdown]
# # Using Pretrained U-net -> Transfer Learning

# %% [markdown]
# # U-Net Pretrained Encoder
# ## using Resnet34 as Backbone
# ## imagenet weights
# ### jaccard loss
#
# ### batch size 16

# %%
#############################################################################
#Use transfer learning using pretrained encoder in the U-Net
#(make sure you uncomment the preprocess_input part in the
# preprocess_data function above)
################################################################
#Define the model
# define model
model = sm.Unet(BACKBONE, encoder_weights='imagenet', 
                input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS),
                classes=n_classes, activation='softmax')
model.compile('Adam', loss=sm.losses.categorical_focal_jaccard_loss, metrics=[sm.metrics.iou_score])
#Other losses to try: categorical_focal_dice_loss, cce_jaccard_loss, cce_dice_loss, categorical_focal_loss

#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)

# %%
print(model.summary())
print(model.input_shape)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 256, 256, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 256, 256, 3)  9           ['data[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0          ['bn_data[0][0]']
#
#  conv0 (Conv2D)                 (None, 128, 128, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 128, 128, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 128, 128, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 130, 130, 64  0          ['relu0[0][0]']
#  D)                             )
#
#  pooling0 (MaxPooling2D)        (None, 64, 64, 64)   0           ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 64, 64, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 64, 64, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage1_unit1_relu1[0][0]']
#  D)
#
#  stage1_unit1_conv1 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_2[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 64, 64, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage1_unit1_relu2[0][0]']
#  D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 64, 64, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                      (None, 64, 64, 64)   0           ['stage1_unit1_conv2[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 64, 64, 64)  256         ['add[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 64, 64, 64)  0           ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_4 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage1_unit2_relu1[0][0]']
#  D)
#
#  stage1_unit2_conv1 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_4[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 64, 64, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage1_unit2_relu2[0][0]']
#  D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_5[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 64)   0           ['stage1_unit2_conv2[0][0]',
#                                                                   'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 64, 64, 64)  256         ['add_1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 64, 64, 64)  0           ['stage1_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_6 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage1_unit3_relu1[0][0]']
#  D)
#
#  stage1_unit3_conv1 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_6[0][0]']
#
#  stage1_unit3_bn2 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu2 (Activation  (None, 64, 64, 64)  0           ['stage1_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage1_unit3_relu2[0][0]']
#  D)
#
#  stage1_unit3_conv2 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_7[0][0]']
#
#  add_2 (Add)                    (None, 64, 64, 64)   0           ['stage1_unit3_conv2[0][0]',
#                                                                   'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 64, 64, 64)  256         ['add_2[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 64, 64, 64)  0           ['stage2_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_8 (ZeroPadding2  (None, 66, 66, 64)  0           ['stage2_unit1_relu1[0][0]']
#  D)
#
#  stage2_unit1_conv1 (Conv2D)    (None, 32, 32, 128)  73728       ['zero_padding2d_8[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 34, 34, 128)  0          ['stage2_unit1_relu2[0][0]']
#  D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_9[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 32, 32, 128)  8192        ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 128)  0           ['stage2_unit1_conv2[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 32, 32, 128)  512        ['add_3[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 32, 32, 128)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_10 (ZeroPadding  (None, 34, 34, 128)  0          ['stage2_unit2_relu1[0][0]']
#  2D)
#
#  stage2_unit2_conv1 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_10[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_11 (ZeroPadding  (None, 34, 34, 128)  0          ['stage2_unit2_relu2[0][0]']
#  2D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_11[0][0]']
#
#  add_4 (Add)                    (None, 32, 32, 128)  0           ['stage2_unit2_conv2[0][0]',
#                                                                   'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 32, 32, 128)  512        ['add_4[0][0]']
#  zation)
#
#  stage2_unit3_relu1 (Activation  (None, 32, 32, 128)  0          ['stage2_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_12 (ZeroPadding  (None, 34, 34, 128)  0          ['stage2_unit3_relu1[0][0]']
#  2D)
#
#  stage2_unit3_conv1 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_12[0][0]']
#
#  stage2_unit3_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit3_conv1[0][0]']
#  zation)
#
#  stage2_unit3_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_13 (ZeroPadding  (None, 34, 34, 128)  0          ['stage2_unit3_relu2[0][0]']
#  2D)
#
#  stage2_unit3_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_13[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 128)  0           ['stage2_unit3_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 32, 32, 128)  512        ['add_5[0][0]']
#  zation)
#
#  stage2_unit4_relu1 (Activation  (None, 32, 32, 128)  0          ['stage2_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_14 (ZeroPadding  (None, 34, 34, 128)  0          ['stage2_unit4_relu1[0][0]']
#  2D)
#
#  stage2_unit4_conv1 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_14[0][0]']
#
#  stage2_unit4_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit4_conv1[0][0]']
#  zation)
#
#  stage2_unit4_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_15 (ZeroPadding  (None, 34, 34, 128)  0          ['stage2_unit4_relu2[0][0]']
#  2D)
#
#  stage2_unit4_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_15[0][0]']
#
#  add_6 (Add)                    (None, 32, 32, 128)  0           ['stage2_unit4_conv2[0][0]',
#                                                                   'add_5[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 32, 32, 128)  512        ['add_6[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 32, 32, 128)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_16 (ZeroPadding  (None, 34, 34, 128)  0          ['stage3_unit1_relu1[0][0]']
#  2D)
#
#  stage3_unit1_conv1 (Conv2D)    (None, 16, 16, 256)  294912      ['zero_padding2d_16[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_17 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_17[0][0]']
#
#  stage3_unit1_sc (Conv2D)       (None, 16, 16, 256)  32768       ['stage3_unit1_relu1[0][0]']
#
#  add_7 (Add)                    (None, 16, 16, 256)  0           ['stage3_unit1_conv2[0][0]',
#                                                                   'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 16, 16, 256)  1024       ['add_7[0][0]']
#  zation)
#
#  stage3_unit2_relu1 (Activation  (None, 16, 16, 256)  0          ['stage3_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_18 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit2_relu1[0][0]']
#  2D)
#
#  stage3_unit2_conv1 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_18[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_19 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_19[0][0]']
#
#  add_8 (Add)                    (None, 16, 16, 256)  0           ['stage3_unit2_conv2[0][0]',
#                                                                   'add_7[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 16, 16, 256)  1024       ['add_8[0][0]']
#  zation)
#
#  stage3_unit3_relu1 (Activation  (None, 16, 16, 256)  0          ['stage3_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_20 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit3_relu1[0][0]']
#  2D)
#
#  stage3_unit3_conv1 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_20[0][0]']
#
#  stage3_unit3_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit3_conv1[0][0]']
#  zation)
#
#  stage3_unit3_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_21 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit3_relu2[0][0]']
#  2D)
#
#  stage3_unit3_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_21[0][0]']
#
#  add_9 (Add)                    (None, 16, 16, 256)  0           ['stage3_unit3_conv2[0][0]',
#                                                                   'add_8[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 16, 16, 256)  1024       ['add_9[0][0]']
#  zation)
#
#  stage3_unit4_relu1 (Activation  (None, 16, 16, 256)  0          ['stage3_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_22 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit4_relu1[0][0]']
#  2D)
#
#  stage3_unit4_conv1 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_22[0][0]']
#
#  stage3_unit4_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit4_conv1[0][0]']
#  zation)
#
#  stage3_unit4_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_23 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit4_relu2[0][0]']
#  2D)
#
#  stage3_unit4_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_23[0][0]']
#
#  add_10 (Add)                   (None, 16, 16, 256)  0           ['stage3_unit4_conv2[0][0]',
#                                                                   'add_9[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 16, 16, 256)  1024       ['add_10[0][0]']
#  zation)
#
#  stage3_unit5_relu1 (Activation  (None, 16, 16, 256)  0          ['stage3_unit5_bn1[0][0]']
#  )
#
#  zero_padding2d_24 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit5_relu1[0][0]']
#  2D)
#
#  stage3_unit5_conv1 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_24[0][0]']
#
#  stage3_unit5_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit5_conv1[0][0]']
#  zation)
#
#  stage3_unit5_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit5_bn2[0][0]']
#  )
#
#  zero_padding2d_25 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit5_relu2[0][0]']
#  2D)
#
#  stage3_unit5_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_25[0][0]']
#
#  add_11 (Add)                   (None, 16, 16, 256)  0           ['stage3_unit5_conv2[0][0]',
#                                                                   'add_10[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, 16, 16, 256)  1024       ['add_11[0][0]']
#  zation)
#
#  stage3_unit6_relu1 (Activation  (None, 16, 16, 256)  0          ['stage3_unit6_bn1[0][0]']
#  )
#
#  zero_padding2d_26 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit6_relu1[0][0]']
#  2D)
#
#  stage3_unit6_conv1 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_26[0][0]']
#
#  stage3_unit6_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit6_conv1[0][0]']
#  zation)
#
#  stage3_unit6_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit6_bn2[0][0]']
#  )
#
#  zero_padding2d_27 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit6_relu2[0][0]']
#  2D)
#
#  stage3_unit6_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_27[0][0]']
#
#  add_12 (Add)                   (None, 16, 16, 256)  0           ['stage3_unit6_conv2[0][0]',
#                                                                   'add_11[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 16, 16, 256)  1024       ['add_12[0][0]']
#  zation)
#
#  stage4_unit1_relu1 (Activation  (None, 16, 16, 256)  0          ['stage4_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_28 (ZeroPadding  (None, 18, 18, 256)  0          ['stage4_unit1_relu1[0][0]']
#  2D)
#
#  stage4_unit1_conv1 (Conv2D)    (None, 8, 8, 512)    1179648     ['zero_padding2d_28[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 8, 8, 512)   0           ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_29 (ZeroPadding  (None, 10, 10, 512)  0          ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_29[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 8, 8, 512)    131072      ['stage4_unit1_relu1[0][0]']
#
#  add_13 (Add)                   (None, 8, 8, 512)    0           ['stage4_unit1_conv2[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 8, 8, 512)   2048        ['add_13[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 8, 8, 512)   0           ['stage4_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_30 (ZeroPadding  (None, 10, 10, 512)  0          ['stage4_unit2_relu1[0][0]']
#  2D)
#
#  stage4_unit2_conv1 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_30[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 8, 8, 512)   0           ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_31 (ZeroPadding  (None, 10, 10, 512)  0          ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_31[0][0]']
#
#  add_14 (Add)                   (None, 8, 8, 512)    0           ['stage4_unit2_conv2[0][0]',
#                                                                   'add_13[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, 8, 8, 512)   2048        ['add_14[0][0]']
#  zation)
#
#  stage4_unit3_relu1 (Activation  (None, 8, 8, 512)   0           ['stage4_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_32 (ZeroPadding  (None, 10, 10, 512)  0          ['stage4_unit3_relu1[0][0]']
#  2D)
#
#  stage4_unit3_conv1 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_32[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit3_conv1[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 8, 8, 512)   0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_33 (ZeroPadding  (None, 10, 10, 512)  0          ['stage4_unit3_relu2[0][0]']
#  2D)
#
#  stage4_unit3_conv2 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_33[0][0]']
#
#  add_15 (Add)                   (None, 8, 8, 512)    0           ['stage4_unit3_conv2[0][0]',
#                                                                   'add_14[0][0]']
#
#  bn1 (BatchNormalization)       (None, 8, 8, 512)    2048        ['add_15[0][0]']
#
#  relu1 (Activation)             (None, 8, 8, 512)    0           ['bn1[0][0]']
#
#  decoder_stage0_upsampling (UpS  (None, 16, 16, 512)  0          ['relu1[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 16, 16, 768)  0          ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 16, 16, 256)  1769472     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 16, 16, 256)  1024       ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 16, 16, 256)  0          ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 16, 16, 256)  589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 16, 16, 256)  1024       ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 16, 16, 256)  0          ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 32, 32, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 32, 32, 384)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 32, 32, 128)  442368      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 32, 32, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 32, 32, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 32, 32, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 32, 32, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 32, 32, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 64, 64, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 64, 64, 192)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 64, 64, 64)   110592      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 64, 64, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 64, 64, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 64, 64, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 64, 64, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 64, 64, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 128, 128, 64  0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage3_concat (Concate  (None, 128, 128, 12  0          ['decoder_stage3_upsampling[0][0]
#  nate)                          8)                               ',
#                                                                   'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 128, 128, 32  36864       ['decoder_stage3_concat[0][0]']
#                                 )
#
#  decoder_stage3a_bn (BatchNorma  (None, 128, 128, 32  128        ['decoder_stage3a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3a_relu (Activati  (None, 128, 128, 32  0          ['decoder_stage3a_bn[0][0]']
#  on)                            )
#
#  decoder_stage3b_conv (Conv2D)  (None, 128, 128, 32  9216        ['decoder_stage3a_relu[0][0]']
#                                 )
#
#  decoder_stage3b_bn (BatchNorma  (None, 128, 128, 32  128        ['decoder_stage3b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3b_relu (Activati  (None, 128, 128, 32  0          ['decoder_stage3b_bn[0][0]']
#  on)                            )
#
#  decoder_stage4_upsampling (UpS  (None, 256, 256, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 256, 256, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 256, 256, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 256, 256, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 256, 256, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 256, 256, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 256, 256, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 256, 256, 2)  290         ['decoder_stage4b_relu[0][0]']
#
#  softmax (Activation)           (None, 256, 256, 2)  0           ['final_conv[0][0]']
#
# ==================================================================================================
# Total params: 24,456,299
# Trainable params: 24,438,949
# Non-trainable params: 17,350
# __________________________________________________________________________________________________
# None
# (None, 256, 256, 3)

# %% [markdown]
# # Fit the model and save it

# %%
#Fit the model
#history = model.fit(my_generator, validation_data=validation_datagen, steps_per_epoch=len(X_train) // 16, validation_steps=len(X_train) // 16, epochs=100)
#Train the model. 
history=model.fit(train_img_gen,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_img_gen,
          validation_steps=val_steps_per_epoch)


model.save('model_30_epochs_batch16_binary.hdf5')
# Out:
# Epoch 1/30
# 57/57 [==============================] - 1424s 25s/step - loss: 0.3642 - iou_score: 0.6881 - val_loss: 0.9300 - val_iou_score: 0.2414
# Epoch 2/30
# 57/57 [==============================] - 1295s 23s/step - loss: 0.3454 - iou_score: 0.7047 - val_loss: 0.7515 - val_iou_score: 0.3242
# Epoch 3/30
# 57/57 [==============================] - 943s 17s/step - loss: 0.3395 - iou_score: 0.7112 - val_loss: 0.7860 - val_iou_score: 0.3179
# Epoch 4/30
# 57/57 [==============================] - 1056s 19s/step - loss: 0.3156 - iou_score: 0.7322 - val_loss: 0.8393 - val_iou_score: 0.3025
# Epoch 5/30
# 57/57 [==============================] - 1074s 19s/step - loss: 0.3074 - iou_score: 0.7391 - val_loss: 1.0597 - val_iou_score: 0.2841
# Epoch 6/30
# 57/57 [==============================] - 1102s 19s/step - loss: 0.3076 - iou_score: 0.7400 - val_loss: 0.9011 - val_iou_score: 0.2862
# Epoch 7/30
# 57/57 [==============================] - 1204s 21s/step - loss: 0.2957 - iou_score: 0.7517 - val_loss: 1.0116 - val_iou_score: 0.2884
# Epoch 8/30
# 57/57 [==============================] - 993s 17s/step - loss: 0.2976 - iou_score: 0.7476 - val_loss: 0.9745 - val_iou_score: 0.2903
# Epoch 9/30
# 57/57 [==============================] - 973s 17s/step - loss: 0.2925 - iou_score: 0.7528 - val_loss: 1.0755 - val_iou_score: 0.3016
# Epoch 10/30
# 57/57 [==============================] - 911s 16s/step - loss: 0.2934 - iou_score: 0.7505 - val_loss: 0.8285 - val_iou_score: 0.3521
# Epoch 11/30
# 57/57 [==============================] - 1147s 20s/step - loss: 0.2829 - iou_score: 0.7613 - val_loss: 1.0035 - val_iou_score: 0.2894
# Epoch 12/30
# 57/57 [==============================] - 1345s 24s/step - loss: 0.2896 - iou_score: 0.7568 - val_loss: 0.6967 - val_iou_score: 0.4316
# Epoch 13/30
# 57/57 [==============================] - 1323s 23s/step - loss: 0.2735 - iou_score: 0.7685 - val_loss: 0.5756 - val_iou_score: 0.5921
# Epoch 14/30
# 57/57 [==============================] - 1347s 24s/step - loss: 0.2673 - iou_score: 0.7756 - val_loss: 0.7830 - val_iou_score: 0.3872
# Epoch 15/30
# 57/57 [==============================] - 1338s 23s/step - loss: 0.2820 - iou_score: 0.7615 - val_loss: 0.4481 - val_iou_score: 0.6535
# Epoch 16/30
# 57/57 [==============================] - 1327s 23s/step - loss: 0.2529 - iou_score: 0.7880 - val_loss: 0.6042 - val_iou_score: 0.5172
# Epoch 17/30
# 57/57 [==============================] - 1328s 23s/step - loss: 0.2578 - iou_score: 0.7822 - val_loss: 0.5546 - val_iou_score: 0.5711
# Epoch 18/30
# 57/57 [==============================] - 1320s 23s/step - loss: 0.2553 - iou_score: 0.7844 - val_loss: 0.4361 - val_iou_score: 0.6591
# Epoch 19/30
# 57/57 [==============================] - 1328s 23s/step - loss: 0.2606 - iou_score: 0.7803 - val_loss: 0.3057 - val_iou_score: 0.7462
# Epoch 20/30
# 57/57 [==============================] - 1366s 24s/step - loss: 0.2429 - iou_score: 0.7944 - val_loss: 0.3144 - val_iou_score: 0.7435
# Epoch 21/30
# 57/57 [==============================] - 1573s 28s/step - loss: 0.2361 - iou_score: 0.8014 - val_loss: 0.3436 - val_iou_score: 0.7361
# Epoch 22/30
# 57/57 [==============================] - 1363s 24s/step - loss: 0.2591 - iou_score: 0.7813 - val_loss: 0.3387 - val_iou_score: 0.7159
# Epoch 23/30
# 57/57 [==============================] - 1540s 27s/step - loss: 0.2376 - iou_score: 0.7999 - val_loss: 0.2954 - val_iou_score: 0.7573
# Epoch 24/30
# 57/57 [==============================] - 1506s 26s/step - loss: 0.2417 - iou_score: 0.7963 - val_loss: 0.2706 - val_iou_score: 0.7741
# Epoch 25/30
# 57/57 [==============================] - 1361s 24s/step - loss: 0.2376 - iou_score: 0.7981 - val_loss: 0.2720 - val_iou_score: 0.7678
# Epoch 26/30
# 57/57 [==============================] - 1304s 23s/step - loss: 0.2307 - iou_score: 0.8072 - val_loss: 0.3659 - val_iou_score: 0.7129
# Epoch 27/30
# 57/57 [==============================] - 1302s 23s/step - loss: 0.2357 - iou_score: 0.8030 - val_loss: 0.2675 - val_iou_score: 0.7901
# Epoch 28/30
# 57/57 [==============================] - 1303s 23s/step - loss: 0.2305 - iou_score: 0.8059 - val_loss: 0.2718 - val_iou_score: 0.7706
# Epoch 29/30
# 57/57 [==============================] - 1291s 23s/step - loss: 0.2242 - iou_score: 0.8120 - val_loss: 0.2486 - val_iou_score: 0.7960
# Epoch 30/30
# 57/57 [==============================] - 1313s 23s/step - loss: 0.2121 - iou_score: 0.8204 - val_loss: 0.2879 - val_iou_score: 0.7727

# %% [markdown]
# # plot the model IoU and loss for training and validation

# %%
#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IoU')
plt.plot(epochs, val_acc, 'r', label='Validation IoU')
plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

# %%
accuracy = history.history['accuracy']
#val_accuracy = history.history['val_accuracy']

#print ("Accuracy", accuracy )
#print ("Accuracy_validation", val_accuracy )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23928/3914117064.py in <module>
# ----> 1 accuracy = history.history['accuracy']
#       2 #val_accuracy = history.history['val_accuracy']
#       3
#       4 #print ("Accuracy", accuracy )
#       5 #print ("Accuracy_validation", val_accuracy )
#
# KeyError: 'accuracy'

# %% [markdown]
# # load the saved model

# %%
from keras.models import load_model

model = load_model("model_30_epochs_batch16_binary.hdf5", compile=False)

#batch_size=32 #Check IoU for a batch of images

#Test generator using validation data.

test_image_batch, test_mask_batch = val_img_gen.__next__()

#Convert categorical to integer for visualization and IoU calculation
test_mask_batch_argmax = np.argmax(test_mask_batch, axis=3) 
test_pred_batch = model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=3)

n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 1/1 [==============================] - 2s 2s/step
# Mean IoU = 0.6954266

# %%
#######################################################
#View a few images, masks and corresponding predictions. 
img_num = random.randint(0, test_image_batch.shape[0]-1)

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_image_batch[img_num])
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_batch_argmax[img_num])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_pred_batch_argmax[img_num])
plt.show()

# %%
#######################################################
#View a few images, masks and corresponding predictions. 
img_num = random.randint(0, test_image_batch.shape[0]-1)

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_image_batch[img_num])
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_batch_argmax[img_num])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_pred_batch_argmax[img_num])
plt.show()
